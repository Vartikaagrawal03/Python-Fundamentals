# %%
## creating a empty dictionary
empty_dict={}
print(type(empty_dict))
# Out:
# <class 'dict'>

# %%
empty_dict=dict()
empty_dict
# Out:
# {}

# %%
student={"name":"Vartika","age":20,"grade":24}
print(student)
print(type(student))
# Out:
# {'name': 'Vartika', 'age': 20, 'grade': 24}
# <class 'dict'>

# %%
## Single key is always used
student={"name":"Vartika","age":20,"name":24}
print(student)
# Out:
# {'name': 24, 'age': 32}

# %%
## accessing dictionary elements
student={"name":"Vartika","age":20,"grade":'A'}
print(student)
# Out:
# {'name': 'Vartika', 'age': 32, 'grade': 'A'}

# %%
print(student['grade'])
print(student['age'])
print(student['name'])
# Out:
# A
# 32
# Vartika

# %%
student['age']=33
student['address']="India"
print(student)
# Out:
# {'name': 'Vartika', 'age': 33, 'grade': 'A', 'address': 'India'}

# %%
del student['grade']
print(student)
# Out:
# {'name': 'Vartika', 'age': 33, 'address': 'India'}

# %%
## dictionary methods
keys=student.keys()
print(keys)
values=student.values()
print(values)
items=student.items()
print(items)
# Out:
# dict_keys(['name', 'age', 'address'])
# dict_values(['Vartika', 33, 'India'])
# dict_items([('name', 'Vartika'), ('age', 33), ('address', 'India')])

# %%
## shallow copy
student_copy=student
print(student_copy)
# Out:
# {'name': 'Vartika', 'age': 33, 'address': 'India'}

# %%
student["name"]="Vidhi"
print(student)
print(student_copy)
# Out:
# {'name': 'Vidhi', 'age': 33, 'address': 'India'}
# {'name': 'Vidhi', 'age': 33, 'address': 'India'}

# %%
## iterating over dictionaries

#iterating over keys
for keys in student.keys():
    print(keys)
# Out:
# name
# age
# address

# %%
#iterating over values
for value in student.values():
    print(values)
# Out:
# dict_values(['Vidhi', 33, 'India'])
# dict_values(['Vidhi', 33, 'India'])
# dict_values(['Vidhi', 33, 'India'])

# %%
## iterate over key value pairs
for key,value in student.items():
    print(f"{key}:{value}")
# Out:
# name:Vartika
# age:20
# grade:24

# %%
## nested dictionary
students={
    "student1":{"name":"Vartika","age":20},
    "student2":{"name":"sambhava","age":21}
}
print(students)
# Out:
# {'student1': {'name': 'Vartika', 'age': 20}, 'student2': {'name': 'sambhava', 'age': 21}}

# %%
## Access nested dictionaries
print(students["student2"]["age"])
print(students["student2"]["name"])
# Out:
# 21
# sambhava

# %%
## iterating over nested dictionaries
for student_id,student_info in students.items():
    print(f"{student_id}:{student_info}")
    for key,value in student_info.items():
        print(f"{key}:{value}")
# Out:
# student1:{'name': 'Vartika', 'age': 20}
# name:Vartika
# age:20
# student2:{'name': 'sambhava', 'age': 21}
# name:sambhava
# age:21

# %%
## use a dictionary to count the frequency of elements in list

numbers=[1,2,2,3,3,3,4,4,4,4]
frequency={}

for number in numbers:
    if number in frequency:
        frequency[number]+=1
    else:
        frequency[number]=1

print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}

# %%
## merge two dictionaries into one

dict1={"a":1,"b":2}
dict2={"b":3,"c":4}
merged_dict={**dict1,**dict2}
print(merged_dict)
# Out:
# {'a': 1, 'b': 3, 'c': 4}
