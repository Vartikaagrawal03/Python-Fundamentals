# %%
lst=[]
print(type(lst))
# Out:
# <class 'list'>

# %%
names=["krish","vartika","sambhava"]
print(names)
# Out:
# ['krish', 'vartika', 'sambhava']

# %%
mixed_list=[1,"vartika",19.8,True]
print(mixed_list)
# Out:
# [1, 'vartika', 19.8, True]

# %%
##Accessing list elements

fruits=["apple","banana","guava","cherry","kiwi"]

# %%
print(fruits[0])
print(fruits[2])
# Out:
# apple
# guava

# %%
print(fruits[1:])
print(fruits[1:3])
# Out:
# ['banana', 'guava', 'cherry', 'kiwi']
# ['banana', 'guava']

# %%
fruits[1]="watermelon"
print(fruits)
# Out:
# ['apple', 'watermelon', 'guava', 'cherry', 'kiwi']

# %%
##list methods
 
fruits.append("orange") ##add an item to the end
print(fruits)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 ##list methods
# ----> 3 fruits.append("orange") ##add an item to the end
#       4 print(fruits)
#
# NameError: name 'fruits' is not defined
